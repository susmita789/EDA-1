# %% [markdown]
# # visualization with pandas plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(21)
df = pd.DataFrame(np.random.rand(1000,1),index = pd.date_range('2022-07-08',periods = 1000),columns = ['mention'])
# sf = pd.DataFrame(np.random.rand(1000,1),index = pd.date_range('2022-07-21',period = 1000),column = ['data'])

# %%
df
# Out:
#              mention
# 2022-07-08  0.048725
# 2022-07-09  0.289110
# 2022-07-10  0.720966
# 2022-07-11  0.021616
# 2022-07-12  0.205923
# ...              ...
# 2025-03-29  0.041565
# 2025-03-30  0.505815
# 2025-03-31  0.895373
# 2025-04-01  0.740316
# 2025-04-02  0.838197
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
bing = df.mention.cumsum()  #this returns the cumulative sum

# %%
bing
# Out:
# 2022-07-08      0.048725
# 2022-07-09      0.337835
# 2022-07-10      1.058801
# 2022-07-11      1.080417
# 2022-07-12      1.286340
#                  ...
# 2025-03-29    498.836583
# 2025-03-30    499.342398
# 2025-03-31    500.237771
# 2025-04-01    500.978087
# 2025-04-02    501.816284
# Freq: D, Name: mention, Length: 1000, dtype: float64

# %%
bing.plot()
# Out:
# <AxesSubplot:>

# %%
df['camly'] = df.mention.cumsum()

# %%
def logarithm(x):
    b = np.log(x)
    return b
df['logarithm'] = df['camly'].apply(logarithm)
df['square'] = df['mention'].apply(lambda x : x**2)

# %%
df
# Out:
#              mention       camly  logarithm    square
# 2022-07-08  0.048725    0.048725  -3.021565  0.002374
# 2022-07-09  0.289110    0.337835  -1.085199  0.083584
# 2022-07-10  0.720966    1.058801   0.057137  0.519792
# 2022-07-11  0.021616    1.080417   0.077347  0.000467
# 2022-07-12  0.205923    1.286340   0.251801  0.042404
# ...              ...         ...        ...       ...
# 2025-03-29  0.041565  498.836583   6.212279  0.001728
# 2025-03-30  0.505815  499.342398   6.213292  0.255849
# 2025-03-31  0.895373  500.237771   6.215084  0.801693
# 2025-04-01  0.740316  500.978087   6.216562  0.548068
# 2025-04-02  0.838197  501.816284   6.218234  0.702574
#
# [1000 rows x 4 columns]

# %%
df.plot(figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
df1 = sns.load_dataset('iris')

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [raw]
# sns.load_dataset('exercise.csv') #you need internet to load the data

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
gf = df1.plot(figsize =(5,5),title = 'irish dataset')  #in x axis we have the index
             #in y axis we have rest of featurespetal lenght showing us maximum dispertion
#petal lenght showing us maximum of dispertion
gf.set_xlabel('INDEX')
gf.set_ylabel('FEATURE')
# Out:
# Text(0, 0.5, 'FEATURE')

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#fetching one data of first row and ist four column
df1.iloc[0][0:4].plot(title = 'setosa',kind = 'pie')
# Out:
# <AxesSubplot:title={'center':'setosa'}, ylabel='0'>

# %%
df1.iloc[0][0:4].plot(title = 'setosa',kind = 'bar')
# Out:
# <AxesSubplot:title={'center':'setosa'}>

# %%
df1.iloc[0][0:4]  #this giving me in series
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df2 = sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df3  = pd.DataFrame(np.random.rand(10,4),columns = ['a','b','c','d'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.029118  0.401694  0.811883  0.218283
# 1  0.203453  0.711304  0.826949  0.153123
# 2  0.893385  0.532053  0.811681  0.543812
# 3  0.776137  0.184288  0.156380  0.894114
# 4  0.112841  0.381271  0.493696  0.441044
# 5  0.979182  0.531122  0.937222  0.173978
# 6  0.596365  0.840430  0.126066  0.377825
# 7  0.725293  0.097983  0.401306  0.373012
# 8  0.810900  0.472127  0.933266  0.546376
# 9  0.161066  0.409767  0.778935  0.170098

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()
#4 overlaped distribution
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['sepal_width']  # the dataset is fluctuating in some value2.0 to 4.4
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(df1['sepal_length'].min())
print(df1['sepal_length'].max())
# Out:
# 4.3
# 7.9

# %%
df1['sepal_length'].plot.hist()  #look at the x range
                                 #b/w 4.3 to 4.8 we have 9 data, b/w 4.9 to 5.3 we have 22 data and so on
#frequency occurace of the data and x axis  it represent range

#seeing the data i can say my data is not evenly distributed it is not evenly skewed 
#we had to do some standard distribution
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['sepal_width'].plot(kind = 'hist',stacked = True,bins=110)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind='hist',stacked = True,bins =120,figsize = (7,7),title = 'HISTOGRAMS OF IRIS',orientation = 'horizontal')
# Out:
# <AxesSubplot:title={'center':'HISTOGRAMS OF IRIS'}, xlabel='Frequency'>

# %%
df1.hist(figsize = (8,8),color = 'brown',alpha = 0.7)  # alpha for contrast
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# # SCATTER PLOT

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#how to understand the relationship between the features
#for this we have to use scatter plot
df1.plot.scatter(x = 'sepal_length', y = 'petal_length')
# in scatter plot you have to give x and y axis
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.plot.scatter(x = 'sepal_length', y = 'sepal_width',label = 'point',s = 100,c = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # HEXABIN

# %%
df1.plot.hexbin(x = 'sepal_length', y = 'petal_width', gridsize= 15)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.hexbin(x = 'sepal_length', y = 'petal_length',gridsize = 18)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.plot.scatter(x = 'sepal_length', y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x = 'sepal_width', y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x = 'sepal_width', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>

# %%
df1.plot.scatter(x = 'petal_length', y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
df1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # when you have to create a dependency on third element

# %%
df1.plot.scatter(x = 'petal_length', y = 'petal_width',c = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
s = df.iloc[2]
s
# Out:
# mention      0.720966
# camly        1.058801
# logarithm    0.057137
# square       0.519792
# Name: 2022-07-10 00:00:00, dtype: float64

# %%
s.plot.pie(figsize =(2,2))
# Out:
# <AxesSubplot:ylabel='2022-07-10 00:00:00'>

# %%
v = df1.T

# %%
iris = df1.head(3).T
iris
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5       3     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris.iloc[0:4].plot.pie(subplots = True,figsize = (20,20),fontsize = 20,autopct = '%.2f')
#autopct gives all the detail
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %% [markdown]
# # i want the relationship to all

# %%
pd.plotting.scatter_matrix(df1,figsize = (10,10),diagonal = 'kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %% [markdown]
# # see the differences

# %%
df['mention'].plot(style = 'r--')
# Out:
# <AxesSubplot:>

# %%
df['mention'].plot(style = 'r--',legend = True)
# Out:
# <AxesSubplot:>

# %%
df['mention'].plot(style = 'r.',legend = True ,label = 'susmita')
# Out:
# <AxesSubplot:>

# %%
df['mention'].plot(style = 'r*',legend = True ,label = 'susmita')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # plotly --interactive and interesting graph

# %%
# !pip install plotly
# !pip install cuffinks
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement cuffinks (from versions: none)
# ERROR: No matching distribution found for cuffinks

# %%
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68727 sha256=c993c21271ef37edd32eb7780b9b9a89510ee79748c3cdfc5444f16082de4c4c
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\6b\76\62\6da97734911ffcbdd559fd1a3f28526321f0ae699182a23866
# Successfully built cufflinks
# ...

# %% [markdown]
# # Welcome to PLOTLY

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls

# cufflinks are configuration file for plotly
import cufflinks as cf

# %%
py.__version__
# Out:
# '5.9.0'

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # it shows us error  so we have to configure this notebook in offline version as iplot present inside plotly offline

# %%
#set inside your system before go to plotly
py.offline.init_notebook_mode(connected = True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
# before
df1.iplot()
#MODULE NOT FOUND ERROR
# Out:
# <div>                            <div id="2f363974-60b6-4f53-b87d-2bb91193a1ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#AFTER MAKING NOTEBOOK AT OFLINE MODE
df1.iplot()
# Out:
# <div>                            <div id="d3134698-0d43-481c-a9fc-b97aaeaf1b35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.iplot(x = 'fare',y ='age',mode = 'markers',colors = 'orange',xTitle = 'fare',yTitle = 'age')
# Out:
# <div>                            <div id="a0440c9c-967c-4a61-92ac-ed5aa9dcb4a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#F5F6F9', 'font': {'color': '#4D5663'}},
#   'paper_bgcolor': '#F5F6F9',
#   'plot_bgcolor': '#F5F6F9',
#   'yaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'titlefont': {'color': '#4D5663'}},
#  'annotations': {'fontcolor': '#4D5663', 'arrowcolor': '#9499A3'},
#  '3d': {'yaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'},
#   'xaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'}}}

# %%
cf.set_config_file(theme = 'solar')
df2.iplot(x = 'fare',y ='age',mode = 'markers',colors = 'orange',xTitle = 'fare',yTitle = 'age')
# Out:
# <div>                            <div id="3072dde9-735d-4411-8543-c3e75c354f4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
