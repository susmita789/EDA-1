# %% [markdown]
# # visualisation using seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'size' , y = 'total_bill',data = tips,hue = 'smoker')

# %%
sns.relplot(x = 'size' , y = 'total_bill',data = tips,hue = 'time')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'size' , y = 'total_bill',data = tips,hue = 'day',style = 'time')

# %%
sns.relplot(x = 'tip',y = 'total_bill',data = tips)

# %%
# separating the data
sns.relplot(x = 'tip',y = 'total_bill',data = tips,hue = 'smoker')

# %%
# separating the data
sns.relplot(x = 'tip',y = 'total_bill',data = tips,hue = 'day')

# %%
#every thursday member comming is smoker or non smoker -------------grouping
sns.relplot(x = 'tip',y = 'total_bill',data = tips,hue = 'day',style = 'smoker')

# %%
sns.relplot(x = 'tip',y = 'total_bill',data = tips,hue = 'day',style = 'smoker',size = 'size')

# %%
sns.relplot(x = 'tip',y = 'total_bill',data = tips ,size = 'size')

# %%
np.random.seed(987)
df = pd.DataFrame(np.random.randn(300,2),columns = ['a','b'])

# %%
df
# Out:
#             a         b
# 0   -1.685927 -1.471120
# 1   -0.111800  1.036370
# 2    0.661040  0.882912
# 3   -1.083328 -0.847132
# 4    0.158278  0.099097
# ..        ...       ...
# 295  0.031179 -0.040179
# 296 -1.388777 -0.797790
# 297  1.063442  1.920314
# 298 -0.331154 -0.909012
# 299 -1.523084 -0.050281
#
# [300 rows x 2 columns]

# %%
sns.relplot(x = 'a' , y = 'b' ,kind = 'line' , data = df )

# %%
sns.relplot(x = 'a' , y = 'b' ,kind = 'line' , data = df,sort = True )

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # SCATTERPLOT

# %%
sns.scatterplot(x = 'sepal_length' , y = 'sepal_width',data = iris )
#in scatter you cannot change
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# day vs total bil in seaborn you had a option for plotting categorical data
#one table categorial and one table is numerical
sns.catplot(x= 'day', y = 'tip',data = tips)

# %%
sns.catplot(x= 'smoker', y = 'tip',data = tips)

# %%
#who has given more tips either male or female
sns.catplot(x= 'day', y = 'tip',data = tips,kind = 'box',hue = 'sex')

# %%
x = np.random.randn(1000)
y = np.random.randn(10000)
z = np.random.randn(100000)

# %%
x

# %%
y
# Out:
# array([ 0.81055671, -0.99167804,  0.30950278, ..., -0.93410452,
#         0.19201137,  1.64520675])

# %%
#lets see wheather this data is normally distributed or not
sns.distplot(x)
# Out:
# D:\a_myconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(y)
# Out:
# D:\a_myconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(z)
#standard normal distribution with mean 0 and std = 1
# Out:
# D:\a_myconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.jointplot(x = tips['total_bill'] , y = tips['tip'] )

# %%
sns.jointplot(x = tips['total_bill'] , y = tips['tip'],kind = 'hex' )

# %%
 iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris)

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = tips)

# %%
#same kind of graph also can receive by regplot
sns.regplot(x = 'total_bill', y = 'tip',data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = tips,col = 'day')
